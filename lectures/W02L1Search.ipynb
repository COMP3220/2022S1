# %% [markdown]
# ### Stop Words

# %%
import nltk

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop = stopwords.words('english')
stop[:5]
# Out:
# ['i', 'me', 'my', 'myself', 'we']

# %% [markdown]
# ### Zipf's Law

# %%
# %matplotlib inline
nltk.download('gutenberg')
import nltk
import collections
import matplotlib.pyplot as plt
words = nltk.corpus.gutenberg.words()
fd = collections.Counter(words)
data = [f for w, f in fd.most_common()]
plt.plot(data[:1000])
plt.title("Zipf's Law")
plt.xlabel("Word rank")
plt.ylabel("Frequency")
# Out:
# [nltk_data] Downloading package gutenberg to /home/jovyan/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# Text(0, 0.5, 'Frequency')

# %%
fd.most_common(10)
# Out:
# [(',', 186091),
#  ('the', 125748),
#  ('and', 78846),
#  ('.', 73746),
#  ('of', 70078),
#  (':', 47406),
#  ('to', 46443),
#  ('a', 32504),
#  ('in', 31959),
#  ('I', 30221)]

# %% [markdown]
# # Vectors and Matrices in Python

# %% [markdown]
# ### Manipulating Vectors

# %%
import numpy as np
a = np.array([1,2,3,4])
a[0]
# Out:
# 1

# %%
a[1:3]
# Out:
# array([2, 3])

# %%
a+1
# Out:
# array([2, 3, 4, 5])

# %%
b = np.array([2,3,4,5])
a+b
# Out:
# array([3, 5, 7, 9])

# %%
np.dot(a,b)
# Out:
# 40

# %% [markdown]
# ### Manipulating Matrices

# %%
x = np.array([[1,2,3],[4,5,6]])
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
y = np.array([[1,1,1],[2,2,2]])
x+y
# Out:
# array([[2, 3, 4],
#        [6, 7, 8]])

# %%
x*y
# Out:
# array([[ 1,  2,  3],
#        [ 8, 10, 12]])

# %%
x.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
np.dot(x.T,y)
# Out:
# array([[ 9,  9,  9],
#        [12, 12, 12],
#        [15, 15, 15]])

# %% [markdown]
# # Scikit-learn
# In the following code, `tfidf` is an instance of the `TfidfVectorizer` class, which
# will accept a list of text files and will ignore stop words.
#
# The `transform` method computes tf.idf of the files. When we do fit and
# transform using the same files, as is the case below, you can combine `fit` and
# `transform` using `fit_transform`.
#
# The output of `transform` (and `fit_transform`) is a sparse matrix. Scikit-learn provides many
# functions that operate with sparse matrices, so often we will not need
# to convert sparse matrices to regular arrays. If we need to convert a
# sparse matrix to an array we can use the `toarray` method.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import zipfile

# %%
import os.path
if not os.path.exists('enron1'):
    with zipfile.ZipFile('enron1.zip') as myzip:
        myzip.extractall()

# %%
import glob
files = glob.glob('enron1/ham/*.txt')
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(input='filename', stop_words='english')
tfidf.fit(files)
tfidf_values = tfidf.transform(files)
len(tfidf.get_feature_names_out())
# Out:
# 19891

# %%
tfidf.get_feature_names_out()[10000:10005]
# Out:
# array(['grandpa', 'grandsn', 'grandsons', 'grant', 'granted'],
#       dtype=object)

# %% [markdown]
# When we execute `tfidf.fit(files)`, sklearn uses the contents of the files to obtain the following information:
#
# * The vocabulary that will be used to determine the columns in the document matrix.
# * The document frequencies, that is, for every word in the vocabulaty, determine how many documents contain the word.
#
# Then, when we execute `tfidf_values = tfidf.transform(newfiles)`, sklearn will determine the term frequencies of the new files (in our example, these are the same files as used in `tfidf.fit(files)`, but we could use different files if we wanted) and return a sparse matrix with the values of tf.idf where:
#
# * Each row of `tfidf_values` represents a document from `newfiles`.
# * Each column of `tfidf_values` represents a word as determined when we executed `tfidf.fit(files)`
#
# The method `get_features_out()` returns a Numpy array with the names of the words used in the vocabulary, so that the first word represents column 1, the second word represents column 2, and so on.
#
# * Older versions of sklearn may use `get_features()` instead, which returns a list (not a Numpy array).
#
# In our example, we used a list of file names as input to `tfidf.transform(files)`. If we wanted to use a list of texts instead, we can use the option 'content', when we create the instance `TfidfVectorizer`, for example: `tfidf = TfidfVectorizer(input='content', stop_words='english')`. See the sklearn documentation for details and further options: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
#
#
# The above code shows that the vocabulary size is 19891, and columns 10000 to 10005 of the document matrix represent the words 'grandpa', 'grandsn', 'grandsons', 'grant', and 'granted'.

# %%
type(tfidf_values)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
type(tfidf_values.toarray())
# Out:
# numpy.ndarray

# %% [markdown]
# The method `shape` returns the dimensions of the array or sparse
# matrix. In our case, the output of the function says that the variable
# `tfidf_values` has 3,672 rows (one row per file) and 19891
# columns (one column per distinct word):

# %%
tfidf_values.shape
# Out:
# (3672, 19891)

# %%
len(files)
# Out:
# 3672

# %% [markdown]
# ### Normalised tf.idf and cosine similarity
#
# In the code below, note that the first character of `l2` is lowercase L (not the number 1).
#
# This code produces normalised tf.idf so that the computation of the
# cosine similarity is faster. To normalise tf.idf, we use the $l^2$ norm,
# which is the standard Euclidean norm.

# %%
import numpy as np
tfidf_norm = TfidfVectorizer(input='filename',
                             stop_words='english',
                             norm='l2')
tfidf_norm_values = tfidf_norm.fit_transform(files).toarray()

# %%
def cosine_similarity(X,Y):
    return np.dot(X,Y)

# %%
cosine_similarity(tfidf_norm_values[0,:],
                  tfidf_norm_values[1,:])
# Out:
# 0.004145058813107748

# %% [markdown]
# The following code shows an alternative way to compute the cosine similarity between two vectors. The sklearn package provides a `cosine_similarity` module (http://scikit-learn.org/stable/modules/metrics.html) that performs the pairwise cosine similarities between the vectors of two lists. The function returns a matrix of cosine similarities where element ($i$,$j$) is the cosine similarity between vector $i$ of the first list, and vector $j$ of the second list. The function does not work with sparse matrices so you need to convert them to numpy arrays.
#
# We can see that the cosine similarity between tfidf vectors is the same as the cosine similarity between normalised tfidf vectors. The code below shows that we must convert the sparse matrix stored in `tfidf_values` by using the method `toarray()`.

# %%
from sklearn.metrics import pairwise
pairwise.cosine_similarity([tfidf_norm_values[0,:]],
                           [tfidf_norm_values[1,:]])
# Out:
# array([[0.00414506]])

# %%
# Don't run this! This code is wrong
#pairwise.cosine_similarity([tfidf_values[0,:]],
#                           [tfidf_values[1,:]])

# %%
dense_tfidf_values = tfidf_values.toarray()
pairwise.cosine_similarity([dense_tfidf_values[0,:]],
                           [dense_tfidf_values[1,:]])
# Out:
# array([[0.00414506]])

# %%
pairwise.cosine_similarity([tfidf_norm_values[0,:]],
                           [tfidf_norm_values[1,:]])
# Out:
# array([[0.00414506]])
